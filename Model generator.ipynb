# %% [markdown]
# <a href="https://colab.research.google.com/github/davidmungai/python-udemy-bootcamp/blob/main/Model%20generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.3MB 7.5MB/s
# ...
#      |████████████████████████████████| 901kB 39.6MB/s
# ...
#      |████████████████████████████████| 3.3MB 40.0MB/s
# ...

# %%
 from transformers import GPT2Tokenizer, AutoModel,GPT2Model, GPT2Config

# %%
configuration = GPT2Config()

# %%
model = GPT2Model.from_pretrained('gpt2')
# Out:
# ...
# Some weights of GPT2Model were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.2.attn.masked_bias', 'h.7.attn.masked_bias', 'h.4.attn.masked_bias', 'h.8.attn.masked_bias', 'h.11.attn.masked_bias', 'h.3.attn.masked_bias', 'h.5.attn.masked_bias', 'h.6.attn.masked_bias', 'h.9.attn.masked_bias', 'h.1.attn.masked_bias', 'h.10.attn.masked_bias', 'h.0.attn.masked_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# %%
numList=tokenizer("Hello world , this is david speaking", return_tensors="pt")['input_ids']

# %%
outputs = model(numList)

# %%
outputs
# Out:
# BaseModelOutputWithPastAndCrossAttentions([('last_hidden_state',
#                                             tensor([[[-9.1356e-06, -1.4021e-01, -2.0845e-01,  ..., -1.5329e-01,
#                                                       -6.7826e-02, -1.9630e-01],
#                                                      [-1.6633e-01,  2.1910e-01,  4.4472e-02,  ..., -1.7681e-01,
#                                                       -1.6563e-01,  4.3342e-01],
#                                                      [ 1.3089e-01,  8.9025e-02,  3.1489e-01,  ...,  2.3399e-02,
#                                                       -5.6595e-02,  8.4737e-02],
#                                                      ...,
#                                                      [-1.3335e-01,  1.2407e-01, -2.8597e-01,  ...,  6.1481e-02,
#                                                        3.0914e-01,  3.7615e-01],
# ...

# %%
tokenizer.decode(numList)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4e1165e82691> in <module>()
# ----> 1 tokenizer.decode(numList)
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py in decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, **kwargs)
#    3087             skip_special_tokens=skip_special_tokens,
#    3088             clean_up_tokenization_spaces=clean_up_tokenization_spaces,
# -> 3089             **kwargs,
#    3090         )
#    3091
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py in _decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, spaces_between_special_tokens, **kwargs)
#     741         self._decode_use_source_tokenizer = kwargs.pop("use_source_tokenizer", False)
#     742
# ...
